# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('ipscanner 10252.xml')

# %%
root = tree.getroot()

# %%
[(x.tag, x.attrib) for x in root]
# Out:
# [('row',
#   {'status': 'alive',
#    'name': 'desc/sipl.cpc.bel',
#    'ip': '10.25.2.1',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:2E:BA:D0',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'srv-rep.cpc.bel',
#    'ip': '10.25.2.2',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:83:0F:FD',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'SRV-DIG',
#    'ip': '10.25.2.3',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:45:B5:EF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'Des-GINF',
#    'os_version': 'Windows',
#    'ip': '10.25.2.4',
#    'manufacturer': 'IBM',
#    'mac': '40:F2:E9:B8:8B:83',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#    'http_title_full': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'Roteador de borda CPC-RC',
#    'device_type': 'Router',
#    'os_version': 'RouterOS',
#    'ip': '10.25.2.5',
#    'manufacturer': 'Routerboard.com',
#    'mac': 'D4:CA:6D:72:DD:B1',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'RouterOS router configuration page (MikroTik router config httpd)',
#    'http_title_full': 'RouterOS router configuration page (MikroTik router config httpd)',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'MikroTik router ftpd 6.28',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': '10.25.2.6',
#    'ip': '10.25.2.6',
#    'manufacturer': 'Dell Inc.',
#    'mac': '00:26:B9:74:30:3F',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CODISSVR',
#    'os_version': 'Windows',
#    'ip': '10.25.2.7',
#    'mac': '52:54:00:3C:1F:22',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'pericianet.cpc.bel',
#    'ip': '10.25.2.8',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:54:4A:BD',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': '10.25.2.9',
#    'ip': '10.25.2.9',
#    'manufacturer': 'IBM',
#    'mac': '40:F2:E9:F4:E0:BA',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': '10.25.2.10',
#    'ip': '10.25.2.10',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:50:56:4B:85:B2',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': '10.25.2.14',
#    'ip': '10.25.2.14',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:0C:4F:29',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0021B73D9EB5',
#    'device_type': 'Printer',
#    'ip': '10.25.2.15',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:3D:9E:B5',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Lexmark CS725 (Lexmark_Web_Server)',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark CS725 printer ftpd CB.031.086',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'WSCPC',
#    'ip': '10.25.2.16',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:78:92:FF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0084EDB05AA1',
#    'device_type': 'Printer',
#    'ip': '10.25.2.19',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:0D:5A:85',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark CS725 printer ftpd CB.020.057',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0084EDB4137F',
#    'device_type': 'Printer',
#    'ip': '10.25.2.20',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:2D:C8:FE',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark CS725 printer ftpd CB.022.062',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0021B7E524C4',
#    'device_type': 'Printer',
#    'ip': '10.25.2.21',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:E5:24:C4',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Lexmark X950 (thttpd)',
#    'http_title_full': 'Lexmark X950 (thttpd)',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark X950 printer ftpd NH.HS30.N304',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0021B71DB296',
#    'device_type': 'Printer',
#    'ip': '10.25.2.22',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:1D:B2:96',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Lexmark MX711',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0021B71D7241',
#    'device_type': 'Printer',
#    'ip': '10.25.2.23',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:1D:72:41',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Lexmark MX711',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0021B71D32F2',
#    'device_type': 'Printer',
#    'ip': '10.25.2.24',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:1D:32:F2',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Lexmark MX711',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-EU9QDS5',
#    'ip': '10.25.2.25',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '34:64:A9:02:DA:45',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FINAN-4510',
#    'ip': '10.25.2.26',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F2:F0',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FINAN-F297',
#    'ip': '10.25.2.27',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:A1',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'MAT-F720',
#    'ip': '10.25.2.28',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '78:E7:D1:AD:4D:22',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'COORDCOF-85LN',
#    'ip': '10.25.2.29',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:EC',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'AVCPC',
#    'ip': '10.25.2.30',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:3C:00:83',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'Des-GINF',
#    'os_version': 'Windows',
#    'ip': '10.25.2.32',
#    'manufacturer': 'IBM',
#    'mac': '40:F2:E9:B8:8B:80',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#    'http_title_full': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'odonto-85l1.cpc.bel',
#    'ip': '10.25.2.33',
#    'mac': '52:54:00:E6:D1:EB',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'fone-f9ps.cpc.bel',
#    'ip': '10.25.2.40',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:49:2B:E7',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'BIBLIOTECA',
#    'ip': '10.25.2.42',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:AA:51:B0',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Apache httpd 2.2.25',
#    'http_title_full': 'Apache httpd 2.2.25 (Win32)',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpl-f7cy.cpc.bel',
#    'ip': '10.25.2.43',
#    'manufacturer': 'Cisco-Linksys, LLC',
#    'mac': 'C0:C1:C0:4C:CD:9D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'LAB-85LK',
#    'ip': '10.25.2.44',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:E4',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'srv-bel.cpc.bel',
#    'ip': '10.25.2.45',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:4D:93:01',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'SRV-IMP',
#    'os_version': 'Windows',
#    'ip': '10.25.2.47',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '2C:41:38:48:CE:81',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'IIS Windows Server (Microsoft IIS httpd 8.5)',
#    'http_title_full': 'IIS Windows Server (Microsoft IIS httpd 8.5)',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'Instrumental-HP',
#    'ip': '10.25.2.48',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:D9:2B:70:FF:44',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'SRV-TS',
#    'ip': '10.25.2.49',
#    'manufacturer': 'VMware, Inc.',
#    'mac': '00:0C:29:4E:EE:EF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0084EDB41351',
#    'device_type': 'Printer',
#    'ip': '10.25.2.50',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:2D:C8:8A',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark CS725 printer ftpd CB.022.062',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'COF-0004',
#    'ip': '10.25.2.51',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:5A:18',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'COF-F7CS',
#    'os_version': 'Windows',
#    'ip': '10.25.2.53',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:9F',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FINAN-F7C9',
#    'ip': '10.25.2.54',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:6F',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'TECMORTO-82Q0',
#    'ip': '10.25.2.55',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:A7',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'RH-F2D5',
#    'ip': '10.25.2.56',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:1B:AF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'rh-b9wt.cpc.bel',
#    'ip': '10.25.2.57',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:61:94',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-D3V1DVI',
#    'ip': '10.25.2.59',
#    'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#    'mac': 'F4:4D:30:85:FE:64',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'RH-7379',
#    'ip': '10.25.2.60',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:77',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'RH-0016',
#    'ip': '10.25.2.61',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:4E:9C',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DAF-85MV',
#    'ip': '10.25.2.62',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:E1',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PERINTER-85MT',
#    'ip': '10.25.2.65',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:1D:33',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GPLAN-85MG',
#    'ip': '10.25.2.67',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:92',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'mat-f27r.cpc.bel',
#    'ip': '10.25.2.69',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:56:A9',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'mat-f2fy.cpc.bel',
#    'ip': '10.25.2.70',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:AF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'mat-2466.cpc.bel',
#    'ip': '10.25.2.71',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:7A:66',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-4C2GT5I',
#    'ip': '10.25.2.73',
#    'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#    'mac': 'F4:4D:30:85:FE:6D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'NTB-FABIOREIS',
#    'ip': '10.25.2.74',
#    'manufacturer': 'ASUSTek COMPUTER INC.',
#    'mac': 'E0:3F:49:F0:52:81',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'WAMPSERVER Homepage (Apache httpd 2.4.33)',
#    'http_title_full': 'WAMPSERVER Homepage (Apache httpd 2.4.33 (Win64) PHP/5.6.35)',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'mat-b6wa.cpc.bel',
#    'ip': '10.25.2.75',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:5E:9A',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DNA-F9Q5',
#    'ip': '10.25.2.76',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'AC:16:2D:34:A8:BB',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CPL-F7CY',
#    'ip': '10.25.2.78',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:AD',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CPL-F7DM',
#    'ip': '10.25.2.80',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F2:F9',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DES-TF',
#    'ip': '10.25.2.81',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '34:64:A9:02:0B:60',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FONE-85LH',
#    'ip': '10.25.2.82',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:FC:7C',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'info-2691.cpc.bel',
#    'ip': '10.25.2.83',
#    'manufacturer': 'Hon Hai Precision Ind. Co.,Ltd.',
#    'mac': '00:1C:25:46:CA:36',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'entsai-f2fq.cpc.bel',
#    'ip': '10.25.2.84',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:FB:02',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-BB1BAK7',
#    'ip': '10.25.2.85',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:10',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'gerinfo-not.cpc.bel',
#    'ip': '10.25.2.87',
#    'manufacturer': 'Cisco-Linksys, LLC',
#    'mac': '00:25:9C:3A:E9:25',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DAF-85L8',
#    'ip': '10.25.2.92',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:FC:97',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-MO06NPN',
#    'ip': '10.25.2.93',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:8D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PROCURA-F2FG',
#    'ip': '10.25.2.94',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:FB:33',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GAB-FVS1-PC',
#    'ip': '10.25.2.98',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'FC:15:B4:D9:EF:5D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'SECICIML-GAQTF',
#    'ip': '10.25.2.99',
#    'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#    'mac': 'F4:4D:30:85:FE:7D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'SECRETA-8558',
#    'ip': '10.25.2.100',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:A6',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'REGI-F2BC',
#    'ip': '10.25.2.104',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:7A:78',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'regi-t1dp.cpc.bel',
#    'ip': '10.25.2.105',
#    'mac': '00:00:00:00:00:00',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DEACA_RENATO_CHAVES_34',
#    'ip': '10.25.2.106',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '00:24:81:24:95:67',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GAB-FBCP',
#    'os_version': 'Windows',
#    'ip': '10.25.2.107',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '2C:59:E5:BE:DE:30',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'gab-f2hl.cpc.bel',
#    'ip': '10.25.2.109',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'AC:16:2D:34:A9:49',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'COAPES-F287',
#    'os_version': 'Windows',
#    'ip': '10.25.2.110',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:34',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Apache httpd 2.2.25',
#    'http_title_full': 'Apache httpd 2.2.25 (Win32)',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'IMPREN-0009',
#    'ip': '10.25.2.112',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:5D:A6',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-OV1N5TH',
#    'ip': '10.25.2.113',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:08',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FONIA-4504',
#    'ip': '10.25.2.114',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:4A',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'recep-f27q.cpc.bel',
#    'ip': '10.25.2.115',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:BA:27',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'almo-0210.cpc.bel',
#    'ip': '10.25.2.121',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '10:1F:74:40:B4:BE',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'psico-c8zv.cpc.bel',
#    'ip': '10.25.2.122',
#    'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#    'mac': '00:1A:6B:59:34:A5',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'BALISTICA--LDZH',
#    'ip': '10.25.2.123',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:81',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GRAFO-F7C5',
#    'ip': '10.25.2.124',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:56',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0021B71D3248',
#    'device_type': 'Printer',
#    'ip': '10.25.2.128',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:1D:32:48',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'Lexmark MX711',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'COMAP-0003',
#    'ip': '10.25.2.130',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:61:95',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PROPAZCPCRC55',
#    'ip': '10.25.2.132',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '10:1F:74:40:B4:4F',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'MORTO-85N2',
#    'ip': '10.25.2.133',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:CF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CORREG-4508',
#    'os_version': 'Windows',
#    'ip': '10.25.2.139',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:A7',
#    'has_http': '1',
#    'is_http8080': '0',
#    'http_title': 'IIS7 (Microsoft IIS httpd 7.5)',
#    'http_title_full': 'IIS7 (Microsoft IIS httpd 7.5)',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'manut-a3dd.cpc.bel',
#    'ip': '10.25.2.141',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:4E:9E',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PSIQ-F2GL',
#    'os_version': 'Windows',
#    'ip': '10.25.2.144',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:A6',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PSQUI-4461',
#    'ip': '10.25.2.145',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:9A',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'psiq-f2cp.cpc.bel',
#    'ip': '10.25.2.146',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:FB:D6',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ENTSAI-F2FQ',
#    'ip': '10.25.2.147',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:A7',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'desktop-7ah2k0i.cpc.bel',
#    'ip': '10.25.2.152',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:0E',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'sexo-f27t.cpc.bel',
#    'ip': '10.25.2.153',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:A3',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cons04-f276.cpc.bel',
#    'ip': '10.25.2.154',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:76',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'almoxar-4468.cpc.bel',
#    'ip': '10.25.2.156',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:1A',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'LABO-E8NF',
#    'ip': '10.25.2.163',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:59',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpvivo-4505.cpc.bel',
#    'ip': '10.25.2.164',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:11',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CPMORTO-F2FT',
#    'ip': '10.25.2.165',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:FB:83',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpmorto-f7bg.cpc.bel',
#    'ip': '10.25.2.168',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:31:50:48:7D:00',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpmorto-b9td.cpc.bel',
#    'ip': '10.25.2.169',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:8B',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-TD498KK',
#    'ip': '10.25.2.170',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:80',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CPVIVO-F2HP',
#    'ip': '10.25.2.171',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:0A:74',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-QB5B8BR',
#    'ip': '10.25.2.172',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:65',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpvivo-f2bq.cpc.bel',
#    'ip': '10.25.2.173',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:7A:3D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpvivo-f2ht.cpc.bel',
#    'ip': '10.25.2.174',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:E4',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'apoiotec-hp.cpc.bel',
#    'ip': '10.25.2.175',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:DD',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'BALI-7369010011',
#    'ip': '10.25.2.176',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:5D:20',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PATRI-F7DV',
#    'ip': '10.25.2.177',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:0E',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'balistica-85m1.cpc.bel',
#    'ip': '10.25.2.178',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:A1',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'balis-0945.cpc.bel',
#    'ip': '10.25.2.179',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:DF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CODLAB-4509',
#    'ip': '10.25.2.181',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:1B',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpl-000092.cpc.bel',
#    'ip': '10.25.2.182',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:7C',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'LABO-1497',
#    'os_version': 'Windows',
#    'ip': '10.25.2.185',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:1A:48',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cengleg-b6ta.cpc.bel',
#    'ip': '10.25.2.189',
#    'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#    'mac': '00:1A:6B:59:1C:54',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FONE-FBFC',
#    'ip': '10.25.2.190',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'A4:5D:36:C2:45:1A',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GPV-85N7',
#    'ip': '10.25.2.191',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:D4',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'explau-4502.cpc.bel',
#    'ip': '10.25.2.192',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:1C',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GRAFO-0023',
#    'ip': '10.25.2.196',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:56:81',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': '10.25.2.197',
#    'ip': '10.25.2.197',
#    'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#    'mac': '00:1A:6B:59:20:B6',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'grafo-f7c5.cpc.bel',
#    'ip': '10.25.2.200',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'AC:16:2D:34:B0:DB',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'cpl-000092.cpc.bel',
#    'ip': '10.25.2.201',
#    'manufacturer': 'TP-LINK TECHNOLOGIES CO.,LTD.',
#    'mac': '14:CC:20:44:8D:81',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DIRIML-F7C8',
#    'ip': '10.25.2.202',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:10',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'DESKTOP-FHLIQ69',
#    'ip': '10.25.2.206',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:52:82:99:7D:57',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'projur-0040.cpc.bel',
#    'ip': '10.25.2.211',
#    'manufacturer': 'PEGATRON CORPORATION',
#    'mac': '7C:05:07:02:4A:D7',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'papi-f2c6.cpc.bel',
#    'ip': '10.25.2.213',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:5B:28',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'papi-1476.cpc.bel',
#    'ip': '10.25.2.214',
#    'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#    'mac': '00:1A:6B:59:20:3C',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'balis-f7df.cpc.bel',
#    'ip': '10.25.2.216',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F2:DF',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'FONE-F9XV',
#    'ip': '10.25.2.217',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'A4:5D:36:C2:47:3E',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'fone-1263.cpc.bel',
#    'ip': '10.25.2.221',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'AC:16:2D:34:A9:3D',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ENG-F7DL',
#    'ip': '10.25.2.223',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F2:EA',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ENGE-1494',
#    'ip': '10.25.2.224',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:31:50:48:4E:73',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'enge-c8fg.cpc.bel',
#    'ip': '10.25.2.226',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:08',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'enge-c8dr.cpc.bel',
#    'ip': '10.25.2.230',
#    'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#    'mac': '00:1A:6B:59:31:AD',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'LAB-F9MD',
#    'ip': '10.25.2.233',
#    'manufacturer': 'Hewlett Packard',
#    'mac': 'AC:16:2D:34:AA:11',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GPV-F7D2',
#    'ip': '10.25.2.234',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F3:19',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ENGE-85KR',
#    'ip': '10.25.2.236',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:0D:88',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'CODONT-F7DP',
#    'ip': '10.25.2.238',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F2:BE',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GPV-85L9',
#    'ip': '10.25.2.243',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:FC:6F',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GPV-4469',
#    'ip': '10.25.2.244',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F2:FA',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'PINFO-F2CQ',
#    'os_version': 'Windows',
#    'ip': '10.25.2.246',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '3C:4A:92:6B:6B:4C',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Microsoft ftpd',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GPIWORK',
#    'ip': '10.25.2.248',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '9C:B6:54:A6:E8:57',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'GRAFO-F7CG',
#    'ip': '10.25.2.249',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '38:EA:A7:19:F4:93',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'VEICULO-ER9K',
#    'ip': '10.25.2.251',
#    'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#    'mac': 'F4:4D:30:85:FE:67',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'Gerencia',
#    'ip': '10.25.2.252',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '64:51:06:1A:FC:90',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ESTGPI_04',
#    'ip': '10.25.2.253',
#    'manufacturer': 'Hewlett Packard',
#    'mac': '40:A8:F0:CB:CB:DE',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '0',
#    'has_rdp': '0',
#    'expanded': '0'}),
#  ('row',
#   {'status': 'alive',
#    'name': 'ET0084EDB403AE',
#    'device_type': 'Printer',
#    'ip': '10.25.2.254',
#    'manufacturer': 'Lexmark International Inc.',
#    'mac': '00:21:B7:2D:C0:75',
#    'has_http': '0',
#    'is_http8080': '0',
#    'has_https': '0',
#    'has_ftp': '1',
#    'ftp_version': 'Lexmark CS725 printer ftpd CB.022.062',
#    'has_rdp': '0',
#    'expanded': '0'})]

# %%
[x.attrib for x in root.iter('row')]
# Out:
# [{'status': 'alive',
#   'name': 'desc/sipl.cpc.bel',
#   'ip': '10.25.2.1',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:2E:BA:D0',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'srv-rep.cpc.bel',
#   'ip': '10.25.2.2',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:83:0F:FD',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'SRV-DIG',
#   'ip': '10.25.2.3',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:45:B5:EF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'Des-GINF',
#   'os_version': 'Windows',
#   'ip': '10.25.2.4',
#   'manufacturer': 'IBM',
#   'mac': '40:F2:E9:B8:8B:83',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#   'http_title_full': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'Roteador de borda CPC-RC',
#   'device_type': 'Router',
#   'os_version': 'RouterOS',
#   'ip': '10.25.2.5',
#   'manufacturer': 'Routerboard.com',
#   'mac': 'D4:CA:6D:72:DD:B1',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'RouterOS router configuration page (MikroTik router config httpd)',
#   'http_title_full': 'RouterOS router configuration page (MikroTik router config httpd)',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'MikroTik router ftpd 6.28',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': '10.25.2.6',
#   'ip': '10.25.2.6',
#   'manufacturer': 'Dell Inc.',
#   'mac': '00:26:B9:74:30:3F',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CODISSVR',
#   'os_version': 'Windows',
#   'ip': '10.25.2.7',
#   'mac': '52:54:00:3C:1F:22',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'pericianet.cpc.bel',
#   'ip': '10.25.2.8',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:54:4A:BD',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': '10.25.2.9',
#   'ip': '10.25.2.9',
#   'manufacturer': 'IBM',
#   'mac': '40:F2:E9:F4:E0:BA',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': '10.25.2.10',
#   'ip': '10.25.2.10',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:50:56:4B:85:B2',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': '10.25.2.14',
#   'ip': '10.25.2.14',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:0C:4F:29',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0021B73D9EB5',
#   'device_type': 'Printer',
#   'ip': '10.25.2.15',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:3D:9E:B5',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Lexmark CS725 (Lexmark_Web_Server)',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark CS725 printer ftpd CB.031.086',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'WSCPC',
#   'ip': '10.25.2.16',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:78:92:FF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0084EDB05AA1',
#   'device_type': 'Printer',
#   'ip': '10.25.2.19',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:0D:5A:85',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark CS725 printer ftpd CB.020.057',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0084EDB4137F',
#   'device_type': 'Printer',
#   'ip': '10.25.2.20',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:2D:C8:FE',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark CS725 printer ftpd CB.022.062',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0021B7E524C4',
#   'device_type': 'Printer',
#   'ip': '10.25.2.21',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:E5:24:C4',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Lexmark X950 (thttpd)',
#   'http_title_full': 'Lexmark X950 (thttpd)',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark X950 printer ftpd NH.HS30.N304',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0021B71DB296',
#   'device_type': 'Printer',
#   'ip': '10.25.2.22',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:1D:B2:96',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Lexmark MX711',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0021B71D7241',
#   'device_type': 'Printer',
#   'ip': '10.25.2.23',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:1D:72:41',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Lexmark MX711',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0021B71D32F2',
#   'device_type': 'Printer',
#   'ip': '10.25.2.24',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:1D:32:F2',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Lexmark MX711',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-EU9QDS5',
#   'ip': '10.25.2.25',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '34:64:A9:02:DA:45',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FINAN-4510',
#   'ip': '10.25.2.26',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F2:F0',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FINAN-F297',
#   'ip': '10.25.2.27',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:A1',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'MAT-F720',
#   'ip': '10.25.2.28',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '78:E7:D1:AD:4D:22',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'COORDCOF-85LN',
#   'ip': '10.25.2.29',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:EC',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'AVCPC',
#   'ip': '10.25.2.30',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:3C:00:83',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'Des-GINF',
#   'os_version': 'Windows',
#   'ip': '10.25.2.32',
#   'manufacturer': 'IBM',
#   'mac': '40:F2:E9:B8:8B:80',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#   'http_title_full': 'Centro de Perícias Renato Chaves (Microsoft IIS httpd 7.5)',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'odonto-85l1.cpc.bel',
#   'ip': '10.25.2.33',
#   'mac': '52:54:00:E6:D1:EB',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'fone-f9ps.cpc.bel',
#   'ip': '10.25.2.40',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:49:2B:E7',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'BIBLIOTECA',
#   'ip': '10.25.2.42',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:AA:51:B0',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Apache httpd 2.2.25',
#   'http_title_full': 'Apache httpd 2.2.25 (Win32)',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpl-f7cy.cpc.bel',
#   'ip': '10.25.2.43',
#   'manufacturer': 'Cisco-Linksys, LLC',
#   'mac': 'C0:C1:C0:4C:CD:9D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'LAB-85LK',
#   'ip': '10.25.2.44',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:E4',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'srv-bel.cpc.bel',
#   'ip': '10.25.2.45',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:4D:93:01',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'SRV-IMP',
#   'os_version': 'Windows',
#   'ip': '10.25.2.47',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '2C:41:38:48:CE:81',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'IIS Windows Server (Microsoft IIS httpd 8.5)',
#   'http_title_full': 'IIS Windows Server (Microsoft IIS httpd 8.5)',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'Instrumental-HP',
#   'ip': '10.25.2.48',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:D9:2B:70:FF:44',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'SRV-TS',
#   'ip': '10.25.2.49',
#   'manufacturer': 'VMware, Inc.',
#   'mac': '00:0C:29:4E:EE:EF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0084EDB41351',
#   'device_type': 'Printer',
#   'ip': '10.25.2.50',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:2D:C8:8A',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark CS725 printer ftpd CB.022.062',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'COF-0004',
#   'ip': '10.25.2.51',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:5A:18',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'COF-F7CS',
#   'os_version': 'Windows',
#   'ip': '10.25.2.53',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:9F',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FINAN-F7C9',
#   'ip': '10.25.2.54',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:6F',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'TECMORTO-82Q0',
#   'ip': '10.25.2.55',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:A7',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'RH-F2D5',
#   'ip': '10.25.2.56',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:1B:AF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'rh-b9wt.cpc.bel',
#   'ip': '10.25.2.57',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:61:94',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-D3V1DVI',
#   'ip': '10.25.2.59',
#   'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#   'mac': 'F4:4D:30:85:FE:64',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'RH-7379',
#   'ip': '10.25.2.60',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:77',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'RH-0016',
#   'ip': '10.25.2.61',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:4E:9C',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DAF-85MV',
#   'ip': '10.25.2.62',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:E1',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PERINTER-85MT',
#   'ip': '10.25.2.65',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:1D:33',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GPLAN-85MG',
#   'ip': '10.25.2.67',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:92',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'mat-f27r.cpc.bel',
#   'ip': '10.25.2.69',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:56:A9',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'mat-f2fy.cpc.bel',
#   'ip': '10.25.2.70',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:AF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'mat-2466.cpc.bel',
#   'ip': '10.25.2.71',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:7A:66',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-4C2GT5I',
#   'ip': '10.25.2.73',
#   'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#   'mac': 'F4:4D:30:85:FE:6D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'NTB-FABIOREIS',
#   'ip': '10.25.2.74',
#   'manufacturer': 'ASUSTek COMPUTER INC.',
#   'mac': 'E0:3F:49:F0:52:81',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'WAMPSERVER Homepage (Apache httpd 2.4.33)',
#   'http_title_full': 'WAMPSERVER Homepage (Apache httpd 2.4.33 (Win64) PHP/5.6.35)',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'mat-b6wa.cpc.bel',
#   'ip': '10.25.2.75',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:5E:9A',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DNA-F9Q5',
#   'ip': '10.25.2.76',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'AC:16:2D:34:A8:BB',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CPL-F7CY',
#   'ip': '10.25.2.78',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:AD',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CPL-F7DM',
#   'ip': '10.25.2.80',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F2:F9',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DES-TF',
#   'ip': '10.25.2.81',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '34:64:A9:02:0B:60',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FONE-85LH',
#   'ip': '10.25.2.82',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:FC:7C',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'info-2691.cpc.bel',
#   'ip': '10.25.2.83',
#   'manufacturer': 'Hon Hai Precision Ind. Co.,Ltd.',
#   'mac': '00:1C:25:46:CA:36',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'entsai-f2fq.cpc.bel',
#   'ip': '10.25.2.84',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:FB:02',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-BB1BAK7',
#   'ip': '10.25.2.85',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:10',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'gerinfo-not.cpc.bel',
#   'ip': '10.25.2.87',
#   'manufacturer': 'Cisco-Linksys, LLC',
#   'mac': '00:25:9C:3A:E9:25',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DAF-85L8',
#   'ip': '10.25.2.92',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:FC:97',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-MO06NPN',
#   'ip': '10.25.2.93',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:8D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PROCURA-F2FG',
#   'ip': '10.25.2.94',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:FB:33',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GAB-FVS1-PC',
#   'ip': '10.25.2.98',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'FC:15:B4:D9:EF:5D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'SECICIML-GAQTF',
#   'ip': '10.25.2.99',
#   'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#   'mac': 'F4:4D:30:85:FE:7D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'SECRETA-8558',
#   'ip': '10.25.2.100',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:A6',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'REGI-F2BC',
#   'ip': '10.25.2.104',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:7A:78',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'regi-t1dp.cpc.bel',
#   'ip': '10.25.2.105',
#   'mac': '00:00:00:00:00:00',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DEACA_RENATO_CHAVES_34',
#   'ip': '10.25.2.106',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '00:24:81:24:95:67',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GAB-FBCP',
#   'os_version': 'Windows',
#   'ip': '10.25.2.107',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '2C:59:E5:BE:DE:30',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'gab-f2hl.cpc.bel',
#   'ip': '10.25.2.109',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'AC:16:2D:34:A9:49',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'COAPES-F287',
#   'os_version': 'Windows',
#   'ip': '10.25.2.110',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:34',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Apache httpd 2.2.25',
#   'http_title_full': 'Apache httpd 2.2.25 (Win32)',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'IMPREN-0009',
#   'ip': '10.25.2.112',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:5D:A6',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-OV1N5TH',
#   'ip': '10.25.2.113',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:08',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FONIA-4504',
#   'ip': '10.25.2.114',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:4A',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'recep-f27q.cpc.bel',
#   'ip': '10.25.2.115',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:BA:27',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'almo-0210.cpc.bel',
#   'ip': '10.25.2.121',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '10:1F:74:40:B4:BE',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'psico-c8zv.cpc.bel',
#   'ip': '10.25.2.122',
#   'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#   'mac': '00:1A:6B:59:34:A5',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'BALISTICA--LDZH',
#   'ip': '10.25.2.123',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:81',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GRAFO-F7C5',
#   'ip': '10.25.2.124',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:56',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0021B71D3248',
#   'device_type': 'Printer',
#   'ip': '10.25.2.128',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:1D:32:48',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'Lexmark MX711',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark MX711 printer ftpd NH63.TU.N638',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'COMAP-0003',
#   'ip': '10.25.2.130',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:61:95',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PROPAZCPCRC55',
#   'ip': '10.25.2.132',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '10:1F:74:40:B4:4F',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'MORTO-85N2',
#   'ip': '10.25.2.133',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:CF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CORREG-4508',
#   'os_version': 'Windows',
#   'ip': '10.25.2.139',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:A7',
#   'has_http': '1',
#   'is_http8080': '0',
#   'http_title': 'IIS7 (Microsoft IIS httpd 7.5)',
#   'http_title_full': 'IIS7 (Microsoft IIS httpd 7.5)',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'manut-a3dd.cpc.bel',
#   'ip': '10.25.2.141',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:4E:9E',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PSIQ-F2GL',
#   'os_version': 'Windows',
#   'ip': '10.25.2.144',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:A6',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PSQUI-4461',
#   'ip': '10.25.2.145',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:9A',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'psiq-f2cp.cpc.bel',
#   'ip': '10.25.2.146',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:FB:D6',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ENTSAI-F2FQ',
#   'ip': '10.25.2.147',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:A7',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'desktop-7ah2k0i.cpc.bel',
#   'ip': '10.25.2.152',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:0E',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'sexo-f27t.cpc.bel',
#   'ip': '10.25.2.153',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:A3',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cons04-f276.cpc.bel',
#   'ip': '10.25.2.154',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:76',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'almoxar-4468.cpc.bel',
#   'ip': '10.25.2.156',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:1A',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'LABO-E8NF',
#   'ip': '10.25.2.163',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:59',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpvivo-4505.cpc.bel',
#   'ip': '10.25.2.164',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:11',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CPMORTO-F2FT',
#   'ip': '10.25.2.165',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:FB:83',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpmorto-f7bg.cpc.bel',
#   'ip': '10.25.2.168',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:31:50:48:7D:00',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpmorto-b9td.cpc.bel',
#   'ip': '10.25.2.169',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:8B',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-TD498KK',
#   'ip': '10.25.2.170',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:80',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CPVIVO-F2HP',
#   'ip': '10.25.2.171',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:0A:74',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-QB5B8BR',
#   'ip': '10.25.2.172',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:65',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpvivo-f2bq.cpc.bel',
#   'ip': '10.25.2.173',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:7A:3D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpvivo-f2ht.cpc.bel',
#   'ip': '10.25.2.174',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:E4',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'apoiotec-hp.cpc.bel',
#   'ip': '10.25.2.175',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:DD',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'BALI-7369010011',
#   'ip': '10.25.2.176',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:5D:20',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PATRI-F7DV',
#   'ip': '10.25.2.177',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:0E',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'balistica-85m1.cpc.bel',
#   'ip': '10.25.2.178',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:A1',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'balis-0945.cpc.bel',
#   'ip': '10.25.2.179',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:DF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CODLAB-4509',
#   'ip': '10.25.2.181',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:1B',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpl-000092.cpc.bel',
#   'ip': '10.25.2.182',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:7C',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'LABO-1497',
#   'os_version': 'Windows',
#   'ip': '10.25.2.185',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:1A:48',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cengleg-b6ta.cpc.bel',
#   'ip': '10.25.2.189',
#   'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#   'mac': '00:1A:6B:59:1C:54',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FONE-FBFC',
#   'ip': '10.25.2.190',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'A4:5D:36:C2:45:1A',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GPV-85N7',
#   'ip': '10.25.2.191',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:D4',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'explau-4502.cpc.bel',
#   'ip': '10.25.2.192',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:1C',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GRAFO-0023',
#   'ip': '10.25.2.196',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:56:81',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': '10.25.2.197',
#   'ip': '10.25.2.197',
#   'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#   'mac': '00:1A:6B:59:20:B6',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'grafo-f7c5.cpc.bel',
#   'ip': '10.25.2.200',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'AC:16:2D:34:B0:DB',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'cpl-000092.cpc.bel',
#   'ip': '10.25.2.201',
#   'manufacturer': 'TP-LINK TECHNOLOGIES CO.,LTD.',
#   'mac': '14:CC:20:44:8D:81',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DIRIML-F7C8',
#   'ip': '10.25.2.202',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:10',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'DESKTOP-FHLIQ69',
#   'ip': '10.25.2.206',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:52:82:99:7D:57',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'projur-0040.cpc.bel',
#   'ip': '10.25.2.211',
#   'manufacturer': 'PEGATRON CORPORATION',
#   'mac': '7C:05:07:02:4A:D7',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'papi-f2c6.cpc.bel',
#   'ip': '10.25.2.213',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:5B:28',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'papi-1476.cpc.bel',
#   'ip': '10.25.2.214',
#   'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#   'mac': '00:1A:6B:59:20:3C',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'balis-f7df.cpc.bel',
#   'ip': '10.25.2.216',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F2:DF',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'FONE-F9XV',
#   'ip': '10.25.2.217',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'A4:5D:36:C2:47:3E',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'fone-1263.cpc.bel',
#   'ip': '10.25.2.221',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'AC:16:2D:34:A9:3D',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ENG-F7DL',
#   'ip': '10.25.2.223',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F2:EA',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ENGE-1494',
#   'ip': '10.25.2.224',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:31:50:48:4E:73',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'enge-c8fg.cpc.bel',
#   'ip': '10.25.2.226',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:08',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'enge-c8dr.cpc.bel',
#   'ip': '10.25.2.230',
#   'manufacturer': 'Universal Global Scientific Industrial Co., Ltd.',
#   'mac': '00:1A:6B:59:31:AD',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'LAB-F9MD',
#   'ip': '10.25.2.233',
#   'manufacturer': 'Hewlett Packard',
#   'mac': 'AC:16:2D:34:AA:11',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GPV-F7D2',
#   'ip': '10.25.2.234',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F3:19',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ENGE-85KR',
#   'ip': '10.25.2.236',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:0D:88',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'CODONT-F7DP',
#   'ip': '10.25.2.238',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F2:BE',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GPV-85L9',
#   'ip': '10.25.2.243',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:FC:6F',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GPV-4469',
#   'ip': '10.25.2.244',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F2:FA',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'PINFO-F2CQ',
#   'os_version': 'Windows',
#   'ip': '10.25.2.246',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '3C:4A:92:6B:6B:4C',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Microsoft ftpd',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GPIWORK',
#   'ip': '10.25.2.248',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '9C:B6:54:A6:E8:57',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'GRAFO-F7CG',
#   'ip': '10.25.2.249',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '38:EA:A7:19:F4:93',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'VEICULO-ER9K',
#   'ip': '10.25.2.251',
#   'manufacturer': 'Elitegroup Computer Systems Co.,Ltd.',
#   'mac': 'F4:4D:30:85:FE:67',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'Gerencia',
#   'ip': '10.25.2.252',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '64:51:06:1A:FC:90',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ESTGPI_04',
#   'ip': '10.25.2.253',
#   'manufacturer': 'Hewlett Packard',
#   'mac': '40:A8:F0:CB:CB:DE',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '0',
#   'has_rdp': '0',
#   'expanded': '0'},
#  {'status': 'alive',
#   'name': 'ET0084EDB403AE',
#   'device_type': 'Printer',
#   'ip': '10.25.2.254',
#   'manufacturer': 'Lexmark International Inc.',
#   'mac': '00:21:B7:2D:C0:75',
#   'has_http': '0',
#   'is_http8080': '0',
#   'has_https': '0',
#   'has_ftp': '1',
#   'ftp_version': 'Lexmark CS725 printer ftpd CB.022.062',
#   'has_rdp': '0',
#   'expanded': '0'}]

# %%
for x in root.iter('row'):
    status = x.get('status')
    name = x.get('name')
    ip = x.get('ip')
    manufacturer = x.get('manufacturer')
    mac = x.get('mac')
    has_http  = x.get('has_http')
    is_http8080 = x.get('is_http8080')
    has_https = x.get('has_https')
    has_ftp = x.get('has_ftp')
    has_rdp = x.get('has_rdp')
    expanded = x.get('expanded')
    os_version = x.get('os_version')
    http_title = x.get('http_title')
    device_type = x.get('device_type')
    http_title_full = ('http_title_full')

# %%
import pymysql as my
